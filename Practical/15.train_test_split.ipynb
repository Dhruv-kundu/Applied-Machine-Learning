# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("placement.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
# Supervised Learning --> Train test split ✔
# UnSupervised Learning --> Train test split X

# %%
#             Data
#             /   \
#     Dependend    Independent 
# Dependent --> output | Independent -->Input

# %%
x = dataset.iloc[:,:-1] # Input (row-->all, column-->except last)
y = dataset["package"] #Output

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.25 )
#random state Hyper parameter tunning for best accuracy

# %%
x , y
# Out:
# (     cgpa
#  0    6.89
#  1    5.12
#  2    7.82
#  3    7.42
#  4    6.94
#  ..    ...
#  195  6.93
#  196  5.89
#  197  7.21
#  198  7.63
#  199  6.22
#
#  [200 rows x 1 columns],
#  0      3.26
#  1      1.98
#  2      3.25
#  3      3.67
#  4      3.57
#         ...
#  195    2.46
#  196    2.57
#  197    3.24
#  198    3.96
#  199    2.33
#  Name: package, Length: 200, dtype: float64)

# %%
x_train, x_test
# Out:
# (     cgpa
#  105  6.66
#  100  7.95
#  85   4.79
#  110  8.18
#  40   9.38
#  ..    ...
#  62   6.34
#  82   5.58
#  125  7.33
#  176  6.29
#  132  5.84
#
#  [150 rows x 1 columns],
#       cgpa
#  41   6.89
#  140  7.91
#  86   7.61
#  198  7.63
#  166  8.60
#  127  6.78
#  148  7.57
#  177  7.09
#  121  6.50
#  187  6.26
#  26   8.31
#  84   4.26
#  111  5.42
#  52   8.37
#  191  7.28
#  27   5.42
#  182  5.88
#  50   9.58
#  3    7.42
#  134  7.20
#  144  6.17
#  109  7.77
#  28   5.94
#  70   5.79
#  122  5.12
#  73   8.44
#  173  6.75
#  20   7.28
#  23   6.19
#  171  8.01
#  164  9.06
#  42   5.95
#  103  7.05
#  179  7.14
#  56   5.84
#  80   7.63
#  69   7.30
#  138  7.91
#  2    7.82
#  22   6.14
#  48   8.63
#  186  7.84
#  131  6.37
#  99   6.61
#  151  6.12
#  60   5.61
#  117  7.12
#  63   9.16
#  145  5.84
#  25   7.28)
