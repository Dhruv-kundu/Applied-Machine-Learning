# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
"""
Multi Linear Regression
It is a n extension of simple linear regression as it takes more than one indepedent or predictor variable to predict the response Variable 
y = m1x1 + m2x2 + m3x3 + .....+ mnxn + c
"""

# %%
dataset = pd.read_csv("Salary_Data.csv")
dataset.head(3)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
dataset.shape
# Out:
# (30, 3)

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.pairplot(data=dataset)
plt.savefig("Pairplot_Multi_Reg")
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True) #
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Salary"]
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.25 , random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train , y_train)
lr.score(x_test,y_test)*100
# Out:
# 92.13567327731518

# %%
lr.coef_
# Out:
# array([4542.40175986, 2767.57088003])

# %%
lr.intercept_
# Out:
# np.float64(-24279.38489676424)

# %%
lr.predict(x_test)
# Out:
# array([118960.22367886,  67167.65572722, 101530.57769495,  74519.75819122,
#         54740.70223941,  57842.17438335, 124907.47579079, 106569.34945491])

# %%
lr.predict(x_test) == y_test
# Out:
# 27    False
# 15    False
# 23    False
# 17    False
# 8     False
# 9     False
# 28    False
# 24    False
# Name: Salary, dtype: bool
