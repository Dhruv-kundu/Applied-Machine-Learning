# %%
"""
Classification Algorithms (Machine Learning)
Classification is used when the target/output is categorical (e.g., Yes/No, Spam/Not Spam, Disease/No Disease).
It is used to identify the category of new observation on the bassis of training data .
Types 
1) Binary Classifier
A classification problem where the target variable has exactly two classes.
Examples: Yes / No, Pass / Fail, Spam / Not Spam, Diabetes / No Diabetes
2)Multi class classifier
A classification problem where the target variable has more than two classes.
Examples: Iris Flower Species (Setosa, Versicolor, Virginica), Digit Recognition (0–9), Animal Classification (Cat, Dog, Bird)

"""

# %%
"""
Types of ML classification Algorithms
Linear Classification Models
Models that separate classes using a straight line (2D), plane (3D), or hyperplane (higher dimensions).

Algorithms
Logistic Regression
Linear SVM (Support Vector Machine with Linear Kernel)
Perceptron
SGD Classifier (Linear Classification)

Class A  ● ● ●
          |
----------|---------
          |
Class B  ▲ ▲ ▲

Non-Linear Classification Models
Models that can learn complex, curved decision boundaries between classes.

Algorithms
K-Nearest Neighbors (KNN)
Decision Tree
Random Forest
Naive Bayes
Neural Networks (ANN, CNN, RNN)

Example
When classes are mixed and require a curved boundary:
      ▲ ▲ ▲
    ▲ ● ● ▲
   ▲ ● ● ● ▲
    ▲ ● ● ▲
      ▲ ▲ ▲
A straight line cannot separate them, but a non-linear boundary can.
"""

# %%
"""
Evaluating A classifier Model
1) Log loss or Cross-entropy loss
2) Confusion Matrix --- IMPORTANT
3)AUC-ROC Curve 
"""
