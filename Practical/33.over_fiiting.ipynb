# %%
"""
What is Overfitting?
Overfitting happens when a machine learning model learns the training data too well, including noise and random patterns, instead of learning the true general pattern.

👉 Result:
Very high accuracy on training data
Poor performance on new (test) data

| Dataset       | Accuracy |
| ------------- | -------- |
| Training data | 99%      |
| Test data     | 60%      |

"""

# %%
"""
How to Check Overfitting?
1. Train vs Test Accuracy Difference

This is the most common method.
train_score = model.score(x_train, y_train)
test_score = model.score(x_test, y_test)

print("Train Accuracy:", train_score)
print("Test Accuracy:", test_score)

| Condition     | Meaning      |
| ------------- | ------------ |
| Train ≈ Test  | Good model   |
| Train >> Test | Overfitting  |
| Both low      | Underfitting |

"""

# %%
# 2. Cross Validation (Better method)
"""
Instead of one split, we test model on multiple splits.

from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=5)
print(scores)
print("Average:", scores.mean())

📌 Interpretation
If scores are consistent → good model
If scores vary a lot → overfitting
"""

# %%
# 3. Learning Curve (Visual method)
"""
We plot training vs validation accuracy.

from sklearn.model_selection import learning_curve
import numpy as np

train_sizes, train_scores, test_scores = learning_curve(
    model, X, y, cv=5
)

print(train_scores.mean(axis=1))
print(test_scores.mean(axis=1))

📌 Pattern
Overfitting graph:
Training accuracy → very high
Test accuracy → much lower
"""
