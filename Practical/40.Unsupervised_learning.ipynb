# %%
# UnSupervised Learning

"""
It is a type of machine learning that learns from unlabeled data { Only Input }
This means the data doesnot have any pre-existing labels or categories
The goal of unsupervised Learning is to discover patterns and relationship in data without NY EXPLICIT program.
                 ┌─────────────────┐
                 │  Raw Data       │
                 │ (Unlabeled)     │
                 └────────┬────────┘
                          │
                          ▼
                 ┌─────────────────┐
                 │ Preprocessing   │
                 │ • Cleaning      │
                 │ • Scaling       │
                 │ • Transformation│
                 └────────┬────────┘
                          │
                          ▼
                 ┌─────────────────┐
                 │ Apply           │
                 │ Unsupervised    │
                 │ Algorithm       │
                 └────────┬────────┘
                          │
          ┌───────────────┴───────────────┐
          │                               │
          ▼                               ▼
 ┌─────────────────┐             ┌─────────────────┐
 │ Clustering      │             │ Association     │
 │ (Grouping Data) │             │ (Finding Rules) │
 └────────┬────────┘             └────────┬────────┘
          │                               │
          ▼                               ▼
 ┌─────────────────┐             ┌─────────────────┐
 │ Hidden Patterns │             │ Relationships   │
 │ & Similarities  │             │ & Associations  │
 └────────┬────────┘             └────────┬────────┘
          │                               │
          └───────────────┬───────────────┘
                          │
                          ▼
                 ┌─────────────────┐
                 │ Final Insights  │
                 │ / Output        │
                 └─────────────────┘
"""

# %%
# Types of Unsupervised Learning Flowchart
"""
                ┌─────────────────┐
                │ Unsupervised    │
                │ Learning        │
                └───────┬─────────┘
                        │
          ┌─────────────┴─────────────┐
          │                           │
          ▼                           ▼
 ┌─────────────────┐        ┌─────────────────┐
 │ Clustering      │        │ Association     │
 │ Group Similar   │        │ Find Relations  │
 │ Data Points     │        │ & Rules         │
 └─────────────────┘        └─────────────────┘
"""

# %%
# Algorithms
"""
K-Means Clustering
Hierarchical Clustering
DBSCAN Clustering
Apriori Algorithm (Association)
Principal Component Analysis (PCA)
"""
